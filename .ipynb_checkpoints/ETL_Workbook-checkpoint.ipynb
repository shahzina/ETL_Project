# %%
import pandas as pd
import csv
import requests
from pprint import pprint
import json
import numpy as np
from citipy import citipy

# %% [markdown]
# ## Yelp Business Data

# %%
y_bus = pd.read_csv("yelp_business.csv")

# %%
y_bus.head()
# Out:
#               business_id                                         categories  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA                           Doctors;Health & Medical
# 1  JwUE5GmEO-sH1FuwJgKBlQ                                        Restaurants
# 2  uGykseHzyS5xAMWoN6YUqA                 American (Traditional);Restaurants
# 3  LRKJF43s9-3jG9Lgx4zODg  Food;Ice Cream & Frozen Yogurt;Fast Food;Resta...
# 4  RgDg-k9S5YD_BaxMckifkg                                Chinese;Restaurants
#
#     latitude  review_count       city  stars
# 0  33.499313             7    Phoenix    3.5
# 1  43.238893            26  De Forest    4.0
# 2  43.252267            16  De Forest    4.0
# 3  43.251045             7  De Forest    4.5
# 4  43.240875             3  De Forest    4.0

# %%
print(len(y_bus))
# Out:
# 42153

# %%
yelp_business = pd.DataFrame(y_bus)
yelp_business.head()
# Out:
#               business_id                                         categories  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA                           Doctors;Health & Medical
# 1  JwUE5GmEO-sH1FuwJgKBlQ                                        Restaurants
# 2  uGykseHzyS5xAMWoN6YUqA                 American (Traditional);Restaurants
# 3  LRKJF43s9-3jG9Lgx4zODg  Food;Ice Cream & Frozen Yogurt;Fast Food;Resta...
# 4  RgDg-k9S5YD_BaxMckifkg                                Chinese;Restaurants
#
#     latitude  review_count       city  stars
# 0  33.499313             7    Phoenix    3.5
# 1  43.238893            26  De Forest    4.0
# 2  43.252267            16  De Forest    4.0
# 3  43.251045             7  De Forest    4.5
# 4  43.240875             3  De Forest    4.0

# %%
type(yelp_business)
# Out:
# pandas.core.frame.DataFrame

# %%
yelp_business.isna().sum()
# Out:
# business_id       0
# categories      339
# latitude          0
# review_count      0
# city              0
# stars             0
# dtype: int64

# %%
yelp_business = yelp_business.dropna(how='any')

# %%
yelp_business.isna().sum()
# Out:
# business_id     0
# categories      0
# latitude        0
# review_count    0
# city            0
# stars           0
# dtype: int64

# %%
yelp_business.duplicated().sum()
# Out:
# 0

# %%
yelp_business.describe()
# Out:
#            latitude  review_count         stars
# count  41814.000000  41814.000000  41814.000000
# mean      36.534810     29.530014      3.677166
# std        5.835889     92.844505      0.884427
# min       32.876638      3.000000      1.000000
# 25%       33.476500      4.000000      3.000000
# 50%       33.678615      8.000000      3.500000
# 75%       36.142010     22.000000      4.500000
# max       56.033777   4084.000000      5.000000

# %% [markdown]
# ### Yelp Reviews

# %%
y_rev = pd.read_csv("yelp_review.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-342209cd9984> in <module>
# ----> 1 y_rev = pd.read_csv("yelp_review.csv")
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'yelp_review.csv' does not exist

# %%
y_rev.head()
# Out:
#                                                 text  votes.cool  \
# 0  dr. goldberg offers everything i look for in a...           1
# 1  Unfortunately, the frustration of being Dr. Go...           0
# 2  Dr. Goldberg has been my doctor for years and ...           1
# 3  Been going to Dr. Goldberg for over 10 years. ...           0
# 4  Got a letter in the mail last week that said D...           1
#
#               business_id  votes.funny  stars       date    type  votes.useful
# 0  vcNAWiLM4dR7D2nwwJ7nCA            0      5  5/17/2007  review             2
# 1  vcNAWiLM4dR7D2nwwJ7nCA            0      2  3/22/2010  review             2
# 2  vcNAWiLM4dR7D2nwwJ7nCA            0      4  2/14/2012  review             1
# 3  vcNAWiLM4dR7D2nwwJ7nCA            0      4   3/2/2012  review             0
# 4  vcNAWiLM4dR7D2nwwJ7nCA            0      4  5/15/2012  review             2

# %%
print(len(y_rev))
# Out:
# 1048575

# %%
yelp_reviews = pd.DataFrame(y_rev)
yelp_reviews.head()
# Out:
#                                                 text  votes.cool  \
# 0  dr. goldberg offers everything i look for in a...           1
# 1  Unfortunately, the frustration of being Dr. Go...           0
# 2  Dr. Goldberg has been my doctor for years and ...           1
# 3  Been going to Dr. Goldberg for over 10 years. ...           0
# 4  Got a letter in the mail last week that said D...           1
#
#               business_id  votes.funny  stars       date    type  votes.useful
# 0  vcNAWiLM4dR7D2nwwJ7nCA            0      5  5/17/2007  review             2
# 1  vcNAWiLM4dR7D2nwwJ7nCA            0      2  3/22/2010  review             2
# 2  vcNAWiLM4dR7D2nwwJ7nCA            0      4  2/14/2012  review             1
# 3  vcNAWiLM4dR7D2nwwJ7nCA            0      4   3/2/2012  review             0
# 4  vcNAWiLM4dR7D2nwwJ7nCA            0      4  5/15/2012  review             2

# %%
type(yelp_reviews)
# Out:
# pandas.core.frame.DataFrame

# %%
yelp_reviews.isna().sum()
# Out:
# text            1
# votes.cool      0
# business_id     0
# votes.funny     0
# stars           0
# date            0
# type            0
# votes.useful    0
# dtype: int64

# %%
yelp_reviews = yelp_reviews.dropna(how = 'any')

# %%
yelp_reviews.isna().sum()
# Out:
# text            0
# votes.cool      0
# business_id     0
# votes.funny     0
# stars           0
# date            0
# type            0
# votes.useful    0
# dtype: int64

# %%
yelp_reviews.duplicated().sum()
# Out:
# 2

# %%
yelp_reviews = yelp_reviews.drop_duplicates()

# %%
yelp_reviews.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Zomato API

# %%
url = "https://developers.zomato.com/api/v2.1/search?"

# %%
header = {"Accept": "application/json", "user_key": "0092256f05a628b53994aec9ae1f30e0"}

response = requests.get(url, headers=header).json()

print(url)
# Out:
# https://developers.zomato.com/api/v2.1/search?

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
total = len(cities)
total
# Out:
# 592

# %%
# %pprint
pprint(response)
# Out:
# Pretty printing has been turned OFF
# {'restaurants': [{'restaurant': {'R': {'res_id': 19013205},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 400,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Burger, Fast Food',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19013205',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/kottayam/kfc-kottayam-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19013205',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Manjooran Tower, '
#                                                          'Kottayam-Kumily '
#                                                          'Road, Kanjikuzhi, '
#                                                          'Kottayam Locality, '
#                                                          'Kottayam',
#                                               'city': 'Kottayam',
#                                               'city_id': 11542,
#                                               'country_id': 1,
#                                               'latitude': '9.5881000000',
#                                               'locality': 'Kottayam Locality',
#                                               'locality_verbose': 'Kottayam '
#                                                                   'Locality, '
#                                                                   'Kottayam',
#                                               'longitude': '76.5400000000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/kottayam/kfc-kottayam-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'KFC',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/kottayam/kfc-kottayam-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 2,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/kottayam/kfc-kottayam-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.8',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': '9ACD32',
#                                                  'rating_text': 'Good',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': '10'}}},
#                  {'restaurant': {'R': {'res_id': 19053865},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 200,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Pizza, Italian, Fast Food, '
#                                              'Continental, Burger',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19053865',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/narnaul/pizza-cafe-narnaul-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 0,
#                                  'has_table_booking': 0,
#                                  'id': '19053865',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Ashok Plaza, Behror '
#                                                          'Chowk, Narnaul, '
#                                                          'Narnaul Locality, '
#                                                          'Narnaul',
#                                               'city': 'Narnaul',
#                                               'city_id': 11578,
#                                               'country_id': 1,
#                                               'latitude': '28.0419040000',
#                                               'locality': 'Narnaul Locality',
#                                               'locality_verbose': 'Narnaul '
#                                                                   'Locality, '
#                                                                   'Narnaul',
#                                               'longitude': '76.1112100000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/narnaul/pizza-cafe-narnaul-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Pizza Cafe',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/narnaul/pizza-cafe-narnaul-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/narnaul/pizza-cafe-narnaul-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 19047550},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 300,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Coffee, Chinese, Pizza',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19047550',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/ambikapur/frespresso-ambikapur-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19047550',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'In front of Ambika '
#                                                          'Petrol Pump, Banaras '
#                                                          'Road, Ambikapur '
#                                                          'chhattisgarh',
#                                               'city': 'Ambikapur',
#                                               'city_id': 11592,
#                                               'country_id': 1,
#                                               'latitude': '23.1328831609',
#                                               'locality': 'Ambikapur Locality',
#                                               'locality_verbose': 'Ambikapur '
#                                                                   'Locality, '
#                                                                   'Ambikapur',
#                                               'longitude': '83.1812097877',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/ambikapur/frespresso-ambikapur-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Frespresso',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/ambikapur/frespresso-ambikapur-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/ambikapur/frespresso-ambikapur-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.5',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': '9ACD32',
#                                                  'rating_text': 'Good',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': '6'}}},
#                  {'restaurant': {'R': {'res_id': 19049860},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 300,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Modern Indian, Chinese',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19049860',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/bahadurgarh/me-n-u-bahadurgarh-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19049860',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Old Kameti Chowk, '
#                                                          'Main Market '
#                                                          'Bahadurgarh, '
#                                                          'Bahadurgarh '
#                                                          'Locality, '
#                                                          'Bahadurgarh',
#                                               'city': 'Bahadurgarh',
#                                               'city_id': 11593,
#                                               'country_id': 1,
#                                               'latitude': '28.6898779581',
#                                               'locality': 'Bahadurgarh '
#                                                           'Locality',
#                                               'locality_verbose': 'Bahadurgarh '
#                                                                   'Locality, '
#                                                                   'Bahadurgarh',
#                                               'longitude': '76.9314287603',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/bahadurgarh/me-n-u-bahadurgarh-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'ME N U ',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/bahadurgarh/me-n-u-bahadurgarh-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/bahadurgarh/me-n-u-bahadurgarh-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.4',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CDD614',
#                                                  'rating_text': 'Average',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': '15'}}},
#                  {'restaurant': {'R': {'res_id': 19064782},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 200,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Biryani, Fast Food',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19064782',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/chhapra/kolkata-royal-biryani-house-chhapra-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 0,
#                                  'has_table_booking': 0,
#                                  'id': '19064782',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Pankaj Cinema Road, '
#                                                          'Opposite State Bank '
#                                                          'Of India, Chhapra '
#                                                          'Locality, Chhapra',
#                                               'city': 'Chhapra',
#                                               'city_id': 11607,
#                                               'country_id': 1,
#                                               'latitude': '25.7782630000',
#                                               'locality': 'Chhapra Locality',
#                                               'locality_verbose': 'Chhapra '
#                                                                   'Locality, '
#                                                                   'Chhapra',
#                                               'longitude': '84.7417970000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/chhapra/kolkata-royal-biryani-house-chhapra-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Kolkata Royal Biryani House',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/chhapra/kolkata-royal-biryani-house-chhapra-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/chhapra/kolkata-royal-biryani-house-chhapra-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 19063303},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 300,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Pizza, Continental, Fast Food',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19063303',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/silchar/dominos-pizza-silchar-locality-silchar-city/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 0,
#                                  'has_table_booking': 0,
#                                  'id': '19063303',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': '3rd Floor, Food '
#                                                          'Court, T-35, '
#                                                          'Goldighi Mall, '
#                                                          'Premtola, Silchar, '
#                                                          'Assam, Silchar '
#                                                          'Locality, Silchar '
#                                                          'City',
#                                               'city': 'Silchar City',
#                                               'city_id': 11516,
#                                               'country_id': 1,
#                                               'latitude': '24.8230032353',
#                                               'locality': 'Silchar Locality',
#                                               'locality_verbose': 'Silchar '
#                                                                   'Locality, '
#                                                                   'Silchar '
#                                                                   'City',
#                                               'longitude': '92.7997306734',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/silchar/dominos-pizza-silchar-locality-silchar-city/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': "Domino's Pizza ",
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/silchar/dominos-pizza-silchar-locality-silchar-city/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/silchar/dominos-pizza-silchar-locality-silchar-city?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 19021341},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 200,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'North Indian, Mughlai, Chinese, '
#                                              'Biryani',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19021341',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/deoghar/bawarchi-services-deoghar-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19021341',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Choudhary Mension, '
#                                                          'Court Road, B '
#                                                          'Deoghar HO, Deoghar '
#                                                          'Locality, Deoghar',
#                                               'city': 'Deoghar',
#                                               'city_id': 11548,
#                                               'country_id': 1,
#                                               'latitude': '24.4915419017',
#                                               'locality': 'Deoghar Locality',
#                                               'locality_verbose': 'Deoghar '
#                                                                   'Locality, '
#                                                                   'Deoghar',
#                                               'longitude': '86.6902965680',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/deoghar/bawarchi-services-deoghar-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Bawarchi Services',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/deoghar/bawarchi-services-deoghar-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/deoghar/bawarchi-services-deoghar-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.6',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': '9ACD32',
#                                                  'rating_text': 'Good',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': '180'}}},
#                  {'restaurant': {'R': {'res_id': 19042304},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 120,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Pizza',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19042304',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/jhajjar/denmark-pizza-jhajjar-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19042304',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Near Ambedkar Chowk '
#                                                          'Opp. Shri shyam '
#                                                          'Mandir, jhajjar, '
#                                                          'Jhajjar Locality, '
#                                                          'Jhajjar',
#                                               'city': 'Jhajjar',
#                                               'city_id': 11577,
#                                               'country_id': 1,
#                                               'latitude': '28.6070198963',
#                                               'locality': 'Jhajjar Locality',
#                                               'locality_verbose': 'Jhajjar '
#                                                                   'Locality, '
#                                                                   'Jhajjar',
#                                               'longitude': '76.6536276788',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/jhajjar/denmark-pizza-jhajjar-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Denmark Pizza ',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/jhajjar/denmark-pizza-jhajjar-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/jhajjar/denmark-pizza-jhajjar-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.6',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': '9ACD32',
#                                                  'rating_text': 'Good',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': '8'}}},
#                  {'restaurant': {'R': {'res_id': 19065978},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 250,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Burger, Fast Food, Sandwich',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19065978',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/muvattupuzha/hayyatt-cafe-and-restaurant-1-muvattupuzha-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19065978',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': '420/AA1A2, '
#                                                          'Muvattupuzha '
#                                                          'Bulding, '
#                                                          'Muvattupuzha Circle, '
#                                                          'Muvattupuzha '
#                                                          'Locality, '
#                                                          'Muvattupuzha',
#                                               'city': 'Muvattupuzha',
#                                               'city_id': 11597,
#                                               'country_id': 1,
#                                               'latitude': '9.9788044314',
#                                               'locality': 'Muvattupuzha '
#                                                           'Locality',
#                                               'locality_verbose': 'Muvattupuzha '
#                                                                   'Locality, '
#                                                                   'Muvattupuzha',
#                                               'longitude': '76.5870116651',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/muvattupuzha/hayyatt-cafe-and-restaurant-1-muvattupuzha-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Hayyatt Cafe and Restaurant',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/muvattupuzha/hayyatt-cafe-and-restaurant-1-muvattupuzha-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/muvattupuzha/hayyatt-cafe-and-restaurant-1-muvattupuzha-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 19050256},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 200,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Pizza, Cafe, Arabian',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19050256',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/chikmagalur/signal-cafe-chikmagalur-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19050256',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Malnad Building NMC '
#                                                          'Circle IG Road, '
#                                                          'Chikmagalur '
#                                                          'Locality, '
#                                                          'Chikmagalur',
#                                               'city': 'Chikmagalur',
#                                               'city_id': 11546,
#                                               'country_id': 1,
#                                               'latitude': '13.3230849838',
#                                               'locality': 'Chikmagalur '
#                                                           'Locality',
#                                               'locality_verbose': 'Chikmagalur '
#                                                                   'Locality, '
#                                                                   'Chikmagalur',
#                                               'longitude': '75.7715634629',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/chikmagalur/signal-cafe-chikmagalur-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Signal Cafe',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/chikmagalur/signal-cafe-chikmagalur-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
# ...
#                                  'location': {'address': 'Near Modi Inter '
#                                                          'College, Mobile '
#                                                          'Market Road, Adarsh '
#                                                          'Nagar, Modinagar '
#                                                          'Locality, Modinagar',
#                                               'city': 'Modinagar',
#                                               'city_id': 11595,
#                                               'country_id': 1,
#                                               'latitude': '28.8355280000',
#                                               'locality': 'Modinagar Locality',
#                                               'locality_verbose': 'Modinagar '
#                                                                   'Locality, '
#                                                                   'Modinagar',
#                                               'longitude': '77.5761390000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/modinagar/meet-restaurant-modinagar-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Meet Restaurant',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/modinagar/meet-restaurant-modinagar-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/modinagar/meet-restaurant-modinagar-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.6',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': '9ACD32',
#                                                  'rating_text': 'Good',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': '8'}}},
#                  {'restaurant': {'R': {'res_id': 18707294},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 250,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'North Indian',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/18707294',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/kota/amar-punjabi-foods-talwandi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': 'https://b.zmtcdn.com/data/pictures/4/18707294/5e9eb3b68de1deaf7590a17b414f017b.jpg?output-format=webp',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '18707294',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 1,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': '4-A-18, Rangbari '
#                                                          'Road, Keshavpura '
#                                                          'Circle, Sector 4, '
#                                                          'Talwandi, Kota',
#                                               'city': 'Kota',
#                                               'city_id': 11302,
#                                               'country_id': 1,
#                                               'latitude': '25.1480382632',
#                                               'locality': 'Talwandi',
#                                               'locality_verbose': 'Talwandi, '
#                                                                   'Kota',
#                                               'longitude': '75.8369738236',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/kota/amar-punjabi-foods-talwandi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Amar Punjabi Foods',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'order_deeplink': '',
#                                  'order_url': 'https://www.zomato.com/kota/amar-punjabi-foods-talwandi/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'photos_url': 'https://www.zomato.com/kota/amar-punjabi-foods-talwandi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': 'https://b.zmtcdn.com/data/pictures/4/18707294/5e9eb3b68de1deaf7590a17b414f017b.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#                                  'url': 'https://www.zomato.com/kota/amar-punjabi-foods-talwandi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '4.8',
#                                                  'rating_color': '3F7E00',
#                                                  'rating_text': 'Excellent',
#                                                  'votes': '2244'}}},
#                  {'restaurant': {'R': {'res_id': 19016647},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 150,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Fast Food, Pizza',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19016647',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/purnea/grill-inn-purnea-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19016647',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'NH 31, Taxi Stand, '
#                                                          'Purnea Locality, '
#                                                          'Purnea',
#                                               'city': 'Purnea',
#                                               'city_id': 11550,
#                                               'country_id': 1,
#                                               'latitude': '25.7723804875',
#                                               'locality': 'Purnea Locality',
#                                               'locality_verbose': 'Purnea '
#                                                                   'Locality, '
#                                                                   'Purnea',
#                                               'longitude': '87.4728669226',
#                                               'zipcode': '854301'},
#                                  'menu_url': 'https://www.zomato.com/purnea/grill-inn-purnea-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Grill Inn',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/purnea/grill-inn-purnea-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/purnea/grill-inn-purnea-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.5',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': '9ACD32',
#                                                  'rating_text': 'Good',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': '101'}}},
#                  {'restaurant': {'R': {'res_id': 18834715},
#                                  'apikey': '0092256f05a628b53994aec9ae1f30e0',
#                                  'average_cost_for_two': 0,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': '',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/18834715',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/raebareli/batohi-restaurant-raebareli-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 0,
#                                  'has_table_booking': 0,
#                                  'id': '18834715',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Rae Bareli, '
#                                                          'Raebareli - 229001, '
#                                                          'Khozanpur, Unchahar, '
#                                                          'Raebareli Locality, '
#                                                          'Raebareli',
#                                               'city': 'Raebareli',
#                                               'city_id': 11418,
#                                               'country_id': 1,
#                                               'latitude': '26.2212520000',
#                                               'locality': 'Raebareli Locality',
#                                               'locality_verbose': 'Raebareli '
#                                                                   'Locality, '
#                                                                   'Raebareli',
#                                               'longitude': '81.2408030000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/raebareli/batohi-restaurant-raebareli-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Batohi Restaurant',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/raebareli/batohi-restaurant-raebareli-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/raebareli/batohi-restaurant-raebareli-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'votes': 0}}}],
#  'results_found': 1417006,
#  'results_shown': 20,
#  'results_start': 0}

# %%
query_url = "https://developers.zomato.com/api/v2.1/search?entity_id="
city_num = 0
api_data = open('output_data/zomato.csv', 'w')
csvwriter = csv.writer(api_data)
header = ['City', 'Restaurant', 'Lat', 'Lng', 'Rating', 'Rating Text']
csvwriter.writerow(header)

for city in cities:
    url_header = {"Accept": "application/json", "user_key": "0092256f05a628b53994aec9ae1f30e0"}
    response = requests.get(query_url + city + '&entity_type=city', headers=url_header).json()
    city_num += 1
    try:
        csvwriter.writerow([response['location']['city'], response['name'], response['location']['latitude'],
                    response['location']['longitude'], response['user_rating']['aggregate_rating'], response['user_rating']['rating_text']])
        print(f"Processing Record {city_num} of {total} | {city}")
    except:
        print(f"City not found. Skipping...")
        continue
api_data.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-4621bec32c98> in <module>
#       1 query_url = "https://developers.zomato.com/api/v2.1/search?entity_id="
#       2 city_num = 0
# ----> 3 api_data = open('output_data/zomato.csv', 'w')
#       4 csvwriter = csv.writer(api_data)
#       5 header = ['City', 'Restaurant', 'Lat', 'Lng', 'Rating', 'Rating Text']
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/zomato.csv'

# %%
url -X GET --header "Accept: application/json" --header "user-key: 4ae5aec1f3577713b3ece44fc9c3d123 " "https://developers.zomato.com/api/v2.1/categories"
